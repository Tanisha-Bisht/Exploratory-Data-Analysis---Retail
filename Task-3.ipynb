# %% [markdown]
# <h1>Exploratory Data Analysis on super store</h1>

# %% [markdown]
# ### Submitted by Tanisha Bisht

# %% [markdown]
# <b>Objective: </b> The objective of this task is to analyse the data of Super store and try to find out the weak areas where we can work to make more profit.

# %% [markdown]
# <b>Language: Python </b>

# %% [markdown]
# <b>Importing libraries</b>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data=pd.read_csv("SampleSuperstore.csv")
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# <b>Getting information about data</b>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data.describe(include='all')
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9994      9994           9994           9994        9994
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5968      5191           9994            915        2001
# mean               NaN       NaN            NaN            NaN         NaN
# std                NaN       NaN            NaN            NaN         NaN
# min                NaN       NaN            NaN            NaN         NaN
# 25%                NaN       NaN            NaN            NaN         NaN
# 50%                NaN       NaN            NaN            NaN         NaN
# 75%                NaN       NaN            NaN            NaN         NaN
# max                NaN       NaN            NaN            NaN         NaN
#
# ...

# %%
data.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# ##### From above we get to know that we have 5 numberic and 8 categorical columns

# %% [markdown]
# <b>Removing Duplicacy</b>

# %%
data.shape
# Out:
# (9994, 13)

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (9977, 13)

# %%
# hence 17 duplicates row removed

# %% [markdown]
# <b>From the above dataset I have conclued that coloumns such as Country , postal code and ship mode can be neglected thus removing those coloums</b>

# %%
data.drop(['Ship Mode','Country','Postal Code'],axis=1,inplace=True)

# %%
data.shape
# Out:
# (9977, 10)

# %%
#checking for duplicacy
data.isnull().sum()
# Out:
# Segment         0
# City            0
# State           0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# ## <b>Univariate analysis</b>

# %%
data['Segment'].value_counts()
# Out:
# Consumer       5183
# Corporate      3015
# Home Office    1779
# Name: Segment, dtype: int64

# %%
plt.figure(figsize=(5,6))
sb.countplot(x='Segment',data=data)
plt.show()

# %%
data['City'].value_counts()
# Out:
# New York City    914
# Los Angeles      746
# Philadelphia     536
# San Francisco    506
# Seattle          424
#                 ...
# Yucaipa            1
# Bartlett           1
# Romeoville         1
# Montebello         1
# Abilene            1
# Name: City, Length: 531, dtype: int64

# %%
data['State'].value_counts()
# Out:
# California              1996
# New York                1127
# Texas                    983
# Pennsylvania             586
# Washington               502
# Illinois                 491
# Ohio                     468
# Florida                  383
# Michigan                 254
# North Carolina           249
# Virginia                 224
# Arizona                  224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   123
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
plt.figure(figsize=(20,15))
sb.countplot(x='State',data=data)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <b>With the help of visualization we can clearly see the variation.Some of the states like California,Texas,New York are performing very well in business where as the countries like Wyoming and west virginia are least performing countries.</b>

# %%
data['Region'].value_counts()
# Out:
# West       3193
# East       2845
# Central    2319
# South      1620
# Name: Region, dtype: int64

# %%
# Region west is giving us more sale
plt.pie(x=data['Region'].value_counts(),labels=['West','East','Central','South'],autopct='%.2f')
plt.show()

# %%
data['Category'].value_counts()
# Out:
# Office Supplies    6012
# Furniture          2118
# Technology         1847
# Name: Category, dtype: int64

# %%
plt.figure(figsize=(5,5))
sb.countplot(x='Category',data=data)
plt.xticks(rotation=90)
plt.show()

# %%
# from all the supplies office supplies are most

# %%
data['Sub-Category'].value_counts()
# Out:
# Binders        1522
# Paper          1359
# Furnishings     956
# Phones          889
# Storage         846
# Art             795
# Accessories     775
# Chairs          615
# Appliances      466
# Labels          363
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
plt.figure(figsize=(10,8))
sb.countplot(x='Sub-Category',data=data)
plt.xticks(rotation=90)
plt.show()

# %%
data['Sales'].value_counts()
# Out:
# 12.960     55
# 19.440     37
# 15.552     37
# 10.368     35
# 25.920     34
#            ..
# 14.720      1
# 376.866     1
# 572.800     1
# 3.928       1
# 629.640     1
# Name: Sales, Length: 5825, dtype: int64

# %%
plt.figure(figsize=(10,5))
sb.histplot(data['Profit'])
plt.show()

# %% [markdown]
# ## <b>Bivariate analysis of profit column with the rest of the columns</b>

# %%
# Comparision of profit regionwise

plt.figure(figsize=(10,7))
data_group=data.groupby(["Region"])["Profit"].sum()
data_group.sort_values(ascending=False)
data_group.plot.bar()
plt.xticks(rotation=360)
plt.show()

# %%
# Comparision of profit citywise

plt.figure(figsize=(10,10))
city_profit=data.groupby(["City"])["Profit"].sum()
a=city_profit[city_profit>3000]
a.sort_values(ascending=False)
a.plot.bar()
plt.xticks(rotation=70)
plt.show()

# %%
#Comparision of profit statewise

plt.figure(figsize=(20,10))
data_group=data.groupby(["State"])["Profit"].sum()
data_group.sort_values(ascending=False)
data_group.plot.bar()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### <u><b>Note: States like California and New York are giving us more profit and states like Texas and Ohio are giving us less profit</b></u>

# %%
#Comparision of profit respective to sales

plt.figure(figsize=(10,5))
sb.scatterplot(data=data, x="Sales", y="Profit")
plt.show()

# %% [markdown]
# #### <u><b>Here we can observe that sale and profit are not depending factor to each other , thus sale is not playing a vital role in increasing the profit </u></b>

# %%
#pairplot
sb.pairplot(data)
plt.show()

# %% [markdown]
# #### <b>Check the correlation between numeric data</b>

# %%
cor_matrix=data.corr()

# %%
plt.figure(figsize=(20,10))
sb.heatmap(cor_matrix,annot=True)
plt.show()

# %% [markdown]
# ## Analysis Outcome

# %% [markdown]
# * Discount is not that affecting on profit hence it should be taken care.Maybe by increasing it affects positive on profit.
# * We should be more careful about the central region as least profit seen there.
# * With the help of heap map we can see the correlaton between sales and profit
